# %%
from selenium import webdriver as wb
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup as bs
import time

# %%
url_main = 'https://www.instagram.com'
url_sub = '/accounts/login/?hl=ko'

login_after_url = 'https://www.instagram.com/explore/tags/python/'
driver = wb.Chrome('../driver/chromedriver.exe')

#driver.get(url_main+url_sub)
driver.get(login_after_url)

# %%
#검색어 입력
input_search = driver.find_element_by_css_selector('input.XTCLo')
input_search.send_keys('충장로')

# %%
soup = bs(driver.page_source,'html.parser')

# %%
#title가져오기
keywords = soup.select('._28KuJ + div > div.uyeeR > span')
print("태그 타이틀 개수 :",len(keywords))

#게시물 수 가져오기(게시물로 시작하는건 div태그 다른 글은 span태그)
boardNum = soup.findAll('div',class_='Fy4o8')
print("태그 게시물 개수 :",len(boardNum))

#주소 가져오기
hrefs = soup.findAll('a',class_='yCE8d')
print("전체 주소 개수 :",len(hrefs))

#주소안에 tags가 있는것들만 가지고오기
new_hrefs = []
for index in range(len(hrefs)):
    if 'tags' in hrefs[index]['href']:
        new_hrefs.append(hrefs[index])
print("태그 주소 개수 :",len(new_hrefs))

# %%
new_hrefs[2]["href"]
# Out:
# '/explore/tags/충장로카페/'

# %%
url_main = 'https://www.instagram.com'
for index in range(len(keywords)):
    print("검색된 키워드 :",keywords[index].text)
    print('키워드 주소 :',url_main+new_hrefs[index]['href'])
    print(boardNum[index].text)
    print('-'*50)
# Out:
# 검색된 키워드 : #충장로
# 키워드 주소 : https://www.instagram.com/explore/tags/충장로/
# 게시물 1,602,622
# --------------------------------------------------
# 검색된 키워드 : #충장로맛집
# 키워드 주소 : https://www.instagram.com/explore/tags/충장로맛집/
# 게시물 186,716
# --------------------------------------------------
# 검색된 키워드 : #충장로카페
# 키워드 주소 : https://www.instagram.com/explore/tags/충장로카페/
# 게시물 54,338
# --------------------------------------------------
# 검색된 키워드 : #충장로옷가게
# 키워드 주소 : https://www.instagram.com/explore/tags/충장로옷가게/
# 게시물 68,090
# --------------------------------------------------
# 검색된 키워드 : #충장로타투
# 키워드 주소 : https://www.instagram.com/explore/tags/충장로타투/
# 게시물 14,854
# --------------------------------------------------
# 검색된 키워드 : #충장로미용실
# 키워드 주소 : https://www.instagram.com/explore/tags/충장로미용실/
# 게시물 31,398
# --------------------------------------------------
# 검색된 키워드 : #충장로네일
# 키워드 주소 : https://www.instagram.com/explore/tags/충장로네일/
# 게시물 46,565
# --------------------------------------------------
# 검색된 키워드 : #충장로네일샵
# 키워드 주소 : https://www.instagram.com/explore/tags/충장로네일샵/
# 게시물 31,594
# --------------------------------------------------
# 검색된 키워드 : #충장로술집
# 키워드 주소 : https://www.instagram.com/explore/tags/충장로술집/
# 게시물 10,522
# --------------------------------------------------
# 검색된 키워드 : #충장로핫플
# 키워드 주소 : https://www.instagram.com/explore/tags/충장로핫플/
# 게시물 6,024
# --------------------------------------------------
# 검색된 키워드 : #충장로속눈썹
# 키워드 주소 : https://www.instagram.com/explore/tags/충장로속눈썹/
# 게시물 15,258
# --------------------------------------------------
# 검색된 키워드 : #충장로눈썹문신
# 키워드 주소 : https://www.instagram.com/explore/tags/충장로눈썹문신/
# 게시물 13,663
# --------------------------------------------------
# 검색된 키워드 : #충장로디져트
# 키워드 주소 : https://www.instagram.com/explore/tags/충장로디져트/
# 게시물 5,497
# --------------------------------------------------
# 검색된 키워드 : #충장로1가
# 키워드 주소 : https://www.instagram.com/explore/tags/충장로1가/
# 게시물 5,509
# --------------------------------------------------
# 검색된 키워드 : #충장로보드카페
# 키워드 주소 : https://www.instagram.com/explore/tags/충장로보드카페/
# 게시물 7,724
# --------------------------------------------------

# %% [markdown]
# ## 첫번째 태그 들어가보기

# %%
driver.get(url_main+new_hrefs[1]['href'])
time.sleep(3)

# %% [markdown]
# ### 첫 번째 게시글 클릭

# %%
btn_board = driver.find_element_by_class_name('eLAPa')#v1Nh3도 가능
btn_board.click()

# %%
soup = bs(driver.page_source,'html.parser')

# %% [markdown]
# ### 작성자, 댓글 가지고오기

# %%
#작성자
writer = soup.find('a',class_='sqdOP')

#댓글작성자, 댓글내용
commenters = soup.findAll('a',class_="sqdOP")[1:] #첫번째사람은 작성자니 제외
comments = soup.select('._6lAjh + span')

print("작성자 : ",writer.text)
print("댓글 작성자 및 개수 :",len(commenters),len(comments))
# Out:
# 작성자 :  chna.y
# 댓글 작성자 및 개수 : 13 13

# %%
for index in range(len(commenters)):
    print('작성자 :',commenters[index].text)
    print('댓글 :',comments[index].text)
    print('-'*30)
# Out:
# 작성자 : chna.y
# 댓글 : 밖은 기분좋은 빗소리..✨#뭐? #막걸리먹고싶다고? #여자의언어
# ------------------------------
# 작성자 : chna.y
# 댓글 : 😘
# ------------------------------
# 작성자 : orlandorosales316
# 댓글 : 👅👅
# ------------------------------
# 작성자 : the_family_cat
# 댓글 : Cutie 😍❤️
# ------------------------------
# 작성자 : 0sin0308
# 댓글 : 귀염 😍👍
# ------------------------------
# 작성자 : bh__542
# 댓글 : 🤩🤩🤩
# ------------------------------
# 작성자 : redhat_an20190615
# 댓글 : 💕
# ------------------------------
# 작성자 : kvbgkds
# 댓글 : 세련됨~~^^👌
# ------------------------------
# 작성자 : won3517
# 댓글 : 😘😘😘😘😘😘😘😘😘❤️❤️❤️❤️❤️❤️❤️❤️
# ------------------------------
# 작성자 : natthapol_yo
# 댓글 : ❤️❤️❤️❤️
# ------------------------------
# 작성자 : zumba.spec
# 댓글 : 오늘 니가꿈에나와쒀~ㅎㅎㅎ
# ------------------------------
# 작성자 : can_6910
# 댓글 : Yeppeun,,,?😍😍😍
# ------------------------------
# 작성자 : kbk_91_
# 댓글 : 애주가의 언어
# ------------------------------

# %% [markdown]
# ### 작성자, 댓글 가져오기 함수로 만들기

# %%
def comment_def():
    #현재 페이지로 긁어오기
    soup = bs(driver.page_source,'html.parser')
    
    #작성자
    writer = soup.find('a',class_='sqdOP')

    #댓글작성자, 댓글내용
    commenters = soup.findAll('a',class_="sqdOP")[1:]
    comments = soup.select('._6lAjh + span')

    for index in range(len(commenters)):
        print('작성자 :',commenters[index].text)
        print('댓글 :',comments[index].text)
        print('-'*30)

# %%
comment_def()
# Out:
# 작성자 : gwangjulife1
# 댓글 : 광주인들이 인정하는 곰탕맛집! #신창동 #이가네나주곰탕밑반찬부터 클라쑤가 다릅니다~~👍수육까지 시켜서 호로록 먹고싶다ㅠ@애두라 오늘 곰탕ㄱㄱ?🙋 #광주맛집#동명동맛집#수완지구맛집#상무지구맛집#충장로맛집#신창동맛집#양림동맛집#용봉동맛집#광주맛집추천#신창동맛집추천#일곡동맛집추천#우산동맛집추천#치평동맛집추천#봉선동맛집추천#효천동맛집
# ------------------------------
# 작성자 : chingfigueroa
# 댓글 : 선팔 좋아욧~~♥
# ------------------------------
# 작성자 : shaundfmcjol
# 댓글 : 자주자주 방문할게용 심심할때 제 피드도 한번 와주세용^^
# ------------------------------
# 작성자 : sitisarahekasrilestari
# 댓글 : 자주자주 방문할게용 심심할때 제 피드도 한번 와주세용^^
# ------------------------------
# 작성자 : lovely_hyang1219
# 댓글 : 오늘은 오리먹는날 오리곰탕도 추천합니다 ㅎ보양식😍
# ------------------------------
# 작성자 : tier_wgts
# 댓글 : 사진 대박..:)
# ------------------------------
# 작성자 : yusnaini596
# 댓글 : 제 피드에도 놀러와 주세요^^
# ------------------------------
# 작성자 : occj.schroedew
# 댓글 : 사진 잘보고 가염:)
# ------------------------------
# 작성자 : naarahweber
# 댓글 : 댓글 남기고 가여 반사 와주시면 센스쟁이^^
# ------------------------------
# 작성자 : lhusy_ronald
# 댓글 : 댓글도장 남기고 갑니닷♥
# ------------------------------
# 작성자 : sa_ndychamkioc
# 댓글 : 오늘도 즐거운 하루 보내욥 우리 모두 더럽! 생각이 많은 요즘이지만 화이팅 하렵니답~^^
# ------------------------------
# 작성자 : l_orenkana
# 댓글 : 반갑습니닷 우리 소통하면서 지내염
# ------------------------------
# 작성자 : elenodwaljd
# 댓글 : 피드 구경하구 갑니다~!우리 자주 소통하는 건 어때요?
# ------------------------------

# %% [markdown]
# ### 옆으로 넘기기 함수

# %%
def nextMove():
    driver.find_element_by_class_name('_65Bje').click()
    time.sleep(2)

# %%
nextMove()

# %% [markdown]
# ## 자동으로 넘어가면서 긁어오기

# %%
for i in range(10):
    nextMove()
    comment_def()
# Out:
# 작성자 : gwangjulife1
# 댓글 : 클라쑤가 다른 소문난 연어 맛집! #동명동 #동명동별관진짜 음식퀄리티 실화냐?..ㄷㄷ맛,비쥬얼 뭣 하나 빠지는게 없음👍@애드라 오늘 연어각이다~🙋.#동명동맛집 #상무지구맛집 #수완지구맛집 #충장로맛집 #동명동핫플 #동명동맛집😋 #동명동핫플레이스 #동명동연어 #동명동연어맛집 #동명동술집추천
# ------------------------------
# 작성자 : gwangjulife1
# 댓글 : #광주맛집 #광주카페
# ------------------------------
# 작성자 : ludivinh_haydep
# 댓글 : 너무좋네요
# ------------------------------
# 작성자 : xuzaya
# 댓글 : 선팔이요~~
# ------------------------------
# 작성자 : ristu_pangi
# 댓글 : 맛있겠다ㅠㅠ
# ------------------------------
# 작성자 : musha_mus_rifah
# 댓글 : 침나오네요..
# ------------------------------
# 작성자 : jjohnny_jkan
# 댓글 : 피드가.좋네요!
# ------------------------------
# 작성자 : simti1jawabi18
# 댓글 : 꼭 가봐야 겠어용^^
# ------------------------------
# 작성자 : rasylia.rahman
# 댓글 : 연어 비쥬얼 미쳤네요..
# ------------------------------
# 작성자 : fofficial_inder_733o
# 댓글 : 여기 느낌맛집인가요?ㅎㅎ
# ------------------------------
# 작성자 : brittjghorna
# 댓글 : 같이 소통해요!!!
# ------------------------------
# 작성자 : nugraha0830
# 댓글 : 피드가 제 취향이네요^^
# ------------------------------
# 작성자 : elis_kelen
# 댓글 : 선팔하고갑니당
# ------------------------------
# 작성자 : gwangjulife1
# 댓글 : 외관은 ㄹㅇ삿포로 ㅇㅈ? 쌍촌 안주맛집! #쌍촌동 #삿뽀로술먹기 너무 편안한 분위기❗안주도 다 맛있고 단골각이다👍@애드라 삿뽀로 ㄱㄱ?
# ------------------------------
# 작성자 : gwangjulife1
# 댓글 : #광주맛집 #동명동맛집 #상무지구맛집 #수완지구맛집 #충장로맛집 #동명동핫플 #동명동맛집😋 #동명동핫플레이스 #동명동연어 #동명동연어맛집 #동명동술집추천
# ------------------------------
# 작성자 : s_anlawrence7804
# 댓글 : 우리 인스타친구해용 먼저 선팔하고 갈게용♥
# ------------------------------
# 작성자 : roneeykhan
# 댓글 : 사진 정말 제 스탈이네요~‼️
# ------------------------------
# 작성자 : rudydragnel
# 댓글 : 가고싶네요!
# ------------------------------
# 작성자 : harraree_bs
# 댓글 : 같이 소통해요!!!
# ------------------------------
# 작성자 : eunho8198
# 댓글 : 도시락 맛나든디
# ------------------------------
# 작성자 : gilangsuganda_37
# 댓글 : 선팔이요~~
# ------------------------------
# 작성자 : watypesek98
# 댓글 : 너무좋네요
# ------------------------------
# 작성자 : cakra_rahadinata
# 댓글 : 사진 넘 괜찮은거 같아염
# ------------------------------
# 작성자 : ave.ligkabernatht
# 댓글 : 좋아염 꾹 눌렀어염^^
# ------------------------------
# 작성자 : hayeon1151
# 댓글 : 삿포로 진짜 맛있는데
# ------------------------------
# 작성자 : ethel_enockristianser
# 댓글 : 우리 이것도 인연인데 소통해여~~^^
# ------------------------------
# 작성자 : gwangjulife1
# 댓글 : 해외보다 더 해외 같은 공간! #진도 #쏠비치야경이 ㄹㅇ 미친듯..ㄷㄷ😍@애들아 우리도 여기 가자ㅠㅠ🙋
# ------------------------------
# 작성자 : gwangjulife1
# 댓글 : #광주맛집 #광주여행 #광주맛집추천 #광주핫플 #광주근교 #광주광역시 #광주카페추천 #수완지구 #수완지구카페 #수완지구맛집 #전대맛집 #전대카페 #전대후문맛집 #동명동카페 #동명동맛집 #충장로맛집 #상무지구맛집 #상무지구카페 #양림동맛집 #양림동카페 #조대 #용봉동맛집 #진도맛집
# ------------------------------
# 작성자 : o.seu_
# 댓글 : @l.j.h39
# ------------------------------
# 작성자 : younpig_13
# 댓글 : @seoyun._.03
# ------------------------------
# 작성자 : gimgyeonghwa7646
# 댓글 : @gwagbyeongyeob
# ------------------------------
# 작성자 : w_jeong_
# 댓글 : @tokki.im 야 여기도 예약
# ------------------------------
# 작성자 : tatianalissy
# 댓글 : @grace_marce10
# ------------------------------
# 작성자 : jiii_hye91
# 댓글 : @hhhobbange
# ------------------------------
# 작성자 : gwangjulife1
# 댓글 : 분위기깡패 일식 오마카세 맛집 #화순 #포테이블진짜 분위기도 좋고 맛도 좋은 곳이 여기임👍좋은날 드라이브겸 데이트코스로 다녀와도 오질듯💕100%예약제라니까 꼭 전화해보고 가자❗@우리도 여기가자ㅠㅠ
# ------------------------------
# 작성자 : gwangjulife1
# 댓글 : #광주맛집 #동명동맛집 #상무지구맛집 #수완지구맛집 #충장로맛집 #동명동핫플 #동명동맛집😋 #동명동핫플레이스 #동명동연어 #동명동연어맛집 #동명동술집추천
# ------------------------------
# 작성자 : mn_a__lu2000
# 댓글 : 선팔하고갑니당
# ------------------------------
# 작성자 : 0730dodomom
# 댓글 : 여기 가고싶어요~~
# ------------------------------
# 작성자 : dame_1400
# 댓글 : 너무좋네요
# ------------------------------
# 작성자 : wasenalkaesse
# 댓글 : 분위기 맛집이네연~~♥
# ------------------------------
# 작성자 : hoitt_3c92b
# 댓글 : 분위기 너무 좋아요~
# ------------------------------
# 작성자 : dendt_milec
# 댓글 : 같이 소통해요!!!
# ------------------------------
# 작성자 : luci_gustriani
# 댓글 : 댓글이랑 좋아요 누르고 가요
# ------------------------------
# 작성자 : adamohuff
# 댓글 : 여기 느낌맛집인가요?ㅎㅎ
# ------------------------------
# 작성자 : cepi_agus_triawan
# 댓글 : 분위기 너무 좋아요~~
# ------------------------------
# 작성자 : roselfmfars
# 댓글 : 여기 느낌맛집인가요?ㅎㅎ
# ------------------------------
# 작성자 : jordynsaige
# 댓글 : 느낌있네요
# ------------------------------
# 작성자 : gwangjulife1
# 댓글 : 우리가 여름을 기다리는 이유!#광주워터밤진짜 항상 역대급 꿀잼으로 난리였음👍08.01(토요일)에 한대요 올 해는 꼭 가보자~~❗@장소는 추후에 공개한대요~~같이 갈 사람?🙋애견동반시 예약해야해요~~~~~~
# ------------------------------
# 작성자 : gwangjulife1
# 댓글 : #광주맛집 #광주라이프 #광주여행 #광주맛집추천 #광주핫플 #광주근교 #광주광역시 #광주카페추천 #수완지구 #수완지구카페 #수완지구맛집 #전대맛집 #전대카페 #전대후문맛집 #동명동카페 #동명동맛집 #충장로맛집 #상무지구맛집 #상무지구카페 #양림동맛집 #양림동카페 #조대 #용봉동맛집 #광주축제
# ------------------------------
# 작성자 : ikomangwirga99
# 댓글 : 사진 감성 되게 괜찮네용 ㅎㅎ 선팔하구가용~~ㅎㅎ
# ------------------------------
# 작성자 : garfield__sum
# 댓글 : ㅋㅋㅋㅋㅋㅋㅇㅋ
# ------------------------------
# 작성자 : jjjjww_jjj
# 댓글 : 코로나😢
# ------------------------------
# 작성자 : bragan_a30ba
# 댓글 : 좋아연 누르고 갑니다 제 피드도 놀러와주세연♥♥
    
    #모든 댓글 긁어오기 해시태그 위치가 항상 다름
    comments = soup.select('._6lAjh + span')
    
    hashtag = []
    for comment in comments:
        #띄어쓰기 기준으로 자르기
        words = comment.text.split()

        for word in words:
            #'#'이 있는것만 가져오기
            if '#' in word:
                #print(word)
                hashtag.append(word)
                
    return hashtag

# %%
#리스트로 반환
comment_hash_def()
# Out:
# ['스타일💖🌈💜#떠먹는케이크..✔️카톡채널',
#  '#꼬케키#광주맛집#광주수제케이크#광주케이크주문#광주',
#  '#광주레터링케이크#용봉동카페#광주핫플#광주디트카페#전대맛집#광주디자인케이크#광주맛집추천#충장로맛집#용봉동맛집#전대맛집#동명동맛집#양림동맛집#동명동카페#광주디저트카페#상무지구맛집#수완지구#수완지구맛집#동명동카페#상무지구#상무지구맛집#광주맛집추천#광주카페#광주빈티지케이크#첨단맛집#쌍촌동맛집#먹스타그램#광주맘#전대상대']

# %%
"""이동하면서 해시태그 수집"""
for i in range(5):
    nextMove()
    for tag in comment_hash_def():
        print(tag)
# Out:
# 귀엽다개🐶💖🐶#꼬케키..✔️카톡채널
# #광주맛집#광주수제케이크#광주케이크주문#광주
# #광주레터링케이크#용봉동카페#광주핫플#광주디트카페#전대맛집#광주디자인케이크#광주맛집추천#충장로맛집#용봉동맛집#전대맛집#동명동맛집#양림동맛집#동명동카페#광주디저트카페#상무지구맛집#수완지구#수완지구맛집#동명동카페#상무지구#상무지구맛집#광주맛집추천#광주카페#광주빈티지케이크#첨단맛집#쌍촌동맛집#먹스타그램#광주맘#전대상대
# #꼬케키#광주맛집#광주수제케이크#광주케이크주문#광주
# #광주레터링케이크#용봉동카페#광주핫플#광주디트카페#전대맛집#광주디자인케이크#광주맛집추천#충장로맛집#용봉동맛집#전대맛집#동명동맛집#양림동맛집#동명동카페#광주디저트카페#상무지구맛집#수완지구#수완지구맛집#동명동카페#상무지구#상무지구맛집#광주맛집추천#광주카페#광주빈티지케이크#첨단맛집#쌍촌동맛집#먹스타그램#광주맘#전대상대
# #좋아요반사
# #댓글반사
# #인친소통
# #일상
# #다렉
# #셀스타그램
# #셀카
# #데일리
# #데일리룩
# #팔로우
# #팔로미
# #선팔하면맞팔
# #선팔
# #맞팔
# #럽스타그램
# #여행스타그램
# #카페
# #뷰티
# #코덕
# #오오티디
# #패션
# #먹스타그램
# #맛집
# #충장로맛집
# #동명동맛집
# #01#00
# #광주맛집#광주수제케이크#광주케이크주문#광주
# #광주레터링케이크#용봉동카페#광주핫플#광주디트카페#전대맛집#광주디자인케이크#광주맛집추천#충장로맛집#용봉동맛집#전대맛집#동명동맛집#양림동맛집#동명동카페#광주디저트카페#상무지구맛집#수완지구#수완지구맛집#동명동카페#상무지구#상무지구맛집#광주맛집추천#광주카페#광주빈티지케이크#첨단맛집#쌍촌동맛집#먹스타그램#광주맘#전대상대#먹부림

# %% [markdown]
# # 해시태그 완벽하게 가져오기

# %%
"""띄어쓰기가 안되어있는 문제 해결 tag_preprocessiong"""
def tag_preprocessiong(ss):
    
    tag_list = []
    for s in ss:
        while True:
            hash1 = s.find("#")#첫번째 #
            hash2 = s.find("#",hash1+1)# 첫번째 # 이후 다음 # 찾아보기
            
            if hash2==-1:
                tag_list.append(s[hash1:].strip())
            else:
                tag_list.append(s[hash1:hash2].strip())
            
            s = s[hash2:]

            if len(s)==1:
                break
    return tag_list

def comment_hash_def():
    #현재 페이지로 긁어오기
    soup = bs(driver.page_source,'html.parser')
    
    #모든 댓글 긁어오기 해시태그 위치가 항상 다름
    comments = soup.select('._6lAjh + span')
    
    hashtag = []
    for comment in comments:
        #띄어쓰기 기준으로 자르기
        word_split = comment.text.split()
        
        # 위의함수추가
        words = tag_preprocessiong(word_split)
        
        for word in words:
            #'#'이 있는것만 가져오기
            if '#' in word:
                #print(word)
                hashtag.append(word)
                
    return hashtag

# %%
comment_hash_def()
# Out:
# ['#광주맛집',
#  '#광주수제케이크',
#  '#광주케이크주문',
#  '#광주',
#  '#광주레터링케이크',
#  '#용봉동카페',
#  '#광주핫플',
#  '#광주디트카페',
#  '#전대맛집',
#  '#광주디자인케이크',
#  '#광주맛집추천',
#  '#충장로맛집',
#  '#용봉동맛집',
#  '#전대맛집',
#  '#동명동맛집',
#  '#양림동맛집',
#  '#동명동카페',
#  '#광주디저트카페',
#  '#상무지구맛집',
#  '#수완지구',
#  '#수완지구맛집',
#  '#동명동카페',
#  '#상무지구',
#  '#상무지구맛집',
#  '#광주맛집추천',
#  '#광주카페',
#  '#광주빈티지케이크',
#  '#첨단맛집',
#  '#쌍촌동맛집',
#  '#먹스타그램',
#  '#광주맘',
#  '#전대상대',
#  '#먹부림']

# %%
"""이동하면서 해시태그 수집"""
for i in range(5):
    nextMove()
    for tag in comment_hash_def():
        print(tag)
# Out:
# #배달의민족
# #떠먹는케이크
# #광주맛집
# #광주수제케이크
# #광주케이크주문
# #광주
# #광주레터링케이크
# #용봉동카페
# #광주핫플
# #광주디트카페
# #전대맛집
# #광주디자인케이크
# #광주맛집추천
# #충장로맛집
# #용봉동맛집
# #전대맛집
# #동명동맛집
# #양림동맛집
# #동명동카페
# #광주디저트카페
# #상무지구맛집
# #수완지구
# #수완지구맛집
# #동명동카페
# #상무지구
# #상무지구맛집
# #광주맛집추천
# #광주카페
# #광주빈티지케이크
# #첨단맛집
# #쌍촌동맛집
# #먹스타그램
# #광주맘
# #전대상대
# #백설공주..✔️카톡채널
# #광주맛집
# #광주수제케이크
# #광주케이크주문
# #광주
# #광주레터링케이크
# #수제케이크
# #용봉동카페
# #광주핫플
# #광주디트카페
# #전대맛집
# #광주디자인케이크
# #광주맛집추천
# #충장로맛집
# #용봉동맛집
# #전대맛집
# #동명동맛집
# #양림동맛집
# #동명동카페
# #광주디저트카페
# #상무지구맛집
# #수완지구
# #수완지구맛집
# #동명동카페
# #상무지구
# #상무지구맛집
# #광주맛집추천
# #광주카페
# #광주빈티지케이크
# #첨단맛집
# #쌍촌동맛집
# #먹스타그램
# #광주맘
# #전대상대
# #전우
