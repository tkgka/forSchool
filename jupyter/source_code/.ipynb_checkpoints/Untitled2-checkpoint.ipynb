# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import platform
from matplotlib import font_manager, rc

plt.rcParams['axes.unicode_minus'] = False

#윈도우
path = "c:/Windows/Fonts/malgun.ttf"
font_name = font_manager.FontProperties(fname=path).get_name()
rc('font', family=font_name)

# %%
t = np.arange(0,10,0.1)
y = np.sin(t)
plt.plot(t,y, color='red',linestyle=':',linewidth='5',marker='*')

# %%
plt.plot([1,2,3,4,5])
plt.show()

# %%
plt.figure(figsize=(5,5))
#sin 함수
plt.plot(t,y, color='red',linestyle=':',linewidth='5',marker='*',label =' sin(t)')
#cosin함수
plt.plot(t,np.cos(t), color='blue', linestyle='--', linewidth='5',marker='o', label = 'cos(t)')
plt.grid()
plt.title("싸인함수")
plt.xlabel('x좌표')
plt.ylabel('y좌표')
plt.ylim(-2,2)
plt.text(6,1.5,"빅데이터분석")
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-0bfd41559c6f> in <module>
#       1 plt.figure(figsize=(5,5))
#       2 #sin 함수
# ----> 3 plt.plot(t,y, color='red',linestyle=':',linewidth='5',marker='*',label = sin(t))
#       4 #cosin함수
#       5 plt.plot(t,np.cos(t), color='blue', linestyle='--', linewidth='5',marker='o', label = cos(t))
#
# NameError: name 'sin' is not defined
