# %%
import pandas as pd
import numpy as np

# %%
list =[[1,2,3],[4,5,6]]

df_list = pd.DataFrame(list, columns = ['col1','col2','col3'])
df_list
# Out:
#    col1  col2  col3
# 0     1     2     3
# 1     4     5     6

# %%
dict = {'col1' : [1,11], 'col2' : [2,22], 'col3' : [3,33]}
df_dict = pd.DataFrame(dict, index = ['one','two'])
df_dict
# Out:
#      col1  col2  col3
# one     1     2     3
# two    11    22    33

# %%
data = {'Name':['chulmin','Eunkyung','jinwoong','Soobeom'],'Year':[2011,2016,2015,2015], 'Gender':['Male','feMale','Male','Male']}
data_df = pd.DataFrame(data, index = ['one','two','three','four'])
data_df
# Out:
#            Name  Year  Gender
# one     chulmin  2011    Male
# two    Eunkyung  2016  feMale
# three  jinwoong  2015    Male
# four    Soobeom  2015    Male

# %%
array = df_dict.values
print('df_dict.values 타입 : ', type(array))
print('df_dict.values shape : ', array.shape)
print(array)
# Out:
# df_dict.values 타입 :  <class 'numpy.ndarray'>
# df_dict.values shape :  (4, 3)
# [['chulmin' 2011 'Male']
#  ['Eunkyung' 2016 'feMale']
#  ['jinwoong' 2015 'Male']
#  ['Soobeom' 2015 'Male']]

# %%
list = df_dict.values.tolist()
print("df_dict.values.tolist() 타입 : ",type(list))
print(list)
# Out:
# df_dict.values.tolist() 타입 :  <class 'list'>
# [['chulmin', 2011, 'Male'], ['Eunkyung', 2016, 'feMale'], ['jinwoong', 2015, 'Male'], ['Soobeom', 2015, 'Male']]

# %%
dict = df_dict.to_dict('list')
print('df_dict.to_dict() 타입 : ',type(dict))
print(dict)
# Out:
# df_dict.to_dict() 타입 :  <class 'dict'>
# {'Name': ['chulmin', 'Eunkyung', 'jinwoong', 'Soobeom'], 'Year': [2011, 2016, 2015, 2015], 'Gender': ['Male', 'feMale', 'Male', 'Male']}

# %%
df_Series = pd.Series(data_df.Gender)
print(df_Series)
# Out:
# one        Male
# two      feMale
# three      Male
# four       Male
# Name: Gender, dtype: object

# %%
df_DF = pd.DataFrame(data_df.Gender)
print(df_DF)
# Out:
#        Gender
# one      Male
# two    feMale
# three    Male
# four     Male

# %%
df_NG = pd.DataFrame([data_df.Name, data_df.Gender])
df_NG
# Out:
#             one       two     three     four
# Name    chulmin  Eunkyung  jinwoong  Soobeom
# Gender     Male    feMale      Male     Male

# %%
data_df2 = data_df.copy()
data_df2
# Out:
#            Name  Year  Gender
# one     chulmin  2011    Male
# two    Eunkyung  2016  feMale
# three  jinwoong  2015    Male
# four    Soobeom  2015    Male

# %%
data_df_reset = data_df2.reset_index()
data_df_reset
# Out:
#    index      Name  Year  Gender
# 0    one   chulmin  2011    Male
# 1    two  Eunkyung  2016  feMale
# 2  three  jinwoong  2015    Male
# 3   four   Soobeom  2015    Male

# %%
data_df_reset = data_df_reset.rename(columns={'index' : 'old_index'})

data_df_reset.index = data_df_reset.index + 1
data_df_reset
# Out:
#   old_index      Name  Year  Gender
# 1       one   chulmin  2011    Male
# 2       two  Eunkyung  2016  feMale
# 3     three  jinwoong  2015    Male
# 4      four   Soobeom  2015    Male

# %%
data_df2.set_index('Year', inplace = True)
data_df2
# Out:
#           Name  Gender
# Year
# 2011   chulmin    Male
# 2016  Eunkyung  feMale
# 2015  jinwoong    Male
# 2015   Soobeom    Male

# %%
array1 = np.arange(start =1, stop = 10)
print(array1)
array2= array1[array1>5]
print(array2)
# Out:
# [1 2 3 4 5 6 7 8 9]
# [6 7 8 9]

# %%
data_df[data_df['Gender'] == 'Male']
# Out:
#            Name  Year Gender
# one     chulmin  2011   Male
# three  jinwoong  2015   Male
# four    Soobeom  2015   Male

# %%
data_df[data_df['Year']>2012]
# Out:
#            Name  Year  Gender
# two    Eunkyung  2016  feMale
# three  jinwoong  2015    Male
# four    Soobeom  2015    Male

# %%
data_df3 = data_df[data_df['Gender'] == 'Male']
data_df3 = data_df3[data_df3['Year']>2012]
data_df3[['Name']]
# Out:
#            Name
# three  jinwoong
# four    Soobeom

# %%
data_df.iloc[1,0]
# Out:
# 'Eunkyung'

# %%
data_df.iloc['one',0]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _has_valid_tuple(self, key)
#     222             try:
# --> 223                 self._validate_key(k, i)
#     224             except ValueError:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_key(self, key, axis)
#    2083             raise ValueError("Can only index by location with "
# -> 2084                              "a [{types}]".format(types=self._valid_types))
#    2085
#
# ValueError: Can only index by location with a [integer, integer slice (START point is INCLUDED, END point is EXCLUDED), listlike of integers, boolean array]
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-182-32f99b3d821f> in <module>
# ----> 1 data_df.iloc['one',0]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1492             except (KeyError, IndexError, AttributeError):
#    1493                 pass
# -> 1494             return self._getitem_tuple(key)
#    1495         else:
#    1496             # we by definition only have the 0th axis
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    2141     def _getitem_tuple(self, tup):
#    2142
# -> 2143         self._has_valid_tuple(tup)
#    2144         try:
#    2145             return self._getitem_lowerdim(tup)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _has_valid_tuple(self, key)
#     225                 raise ValueError("Location based indexing can only have "
#     226                                  "[{types}] types"
# --> 227                                  .format(types=self._valid_types))
#     228
#     229     def _is_nested_tuple_indexer(self, tup):
#
# ValueError: Location based indexing can only have [integer, integer slice (START point is INCLUDED, END point is EXCLUDED), listlike of integers, boolean array] types

# %%
data_df.iloc[1:3]
# Out:
#        Year
# two    2016
# three  2015

# %%
data_df.iloc[0:3:2, 0:2]
# Out:
#            Name  Year
# one     chulmin  2011
# three  jinwoong  2015

# %%
data_df.loc['one', 'Name']
# Out:
# 'chulmin'

# %%
data_df_reset.loc[1,'Name']
# Out:
# 'chulmin'

# %%
data_df_reset.loc[1:2,'Name']
# Out:
# 1    Eunkyung
# 2    jinwoong
# Name: Name, dtype: object

# %%
titanic_df= pd.read_csv("../data/titanic_train.csv", encoding="utf-8")

# %%
titanic_df.isna().head(3)
# Out:
#    PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0        False     False   False  False  False  False  False  False   False
# 1        False     False   False  False  False  False  False  False   False
# 2        False     False   False  False  False  False  False  False   False
#
#     Fare  Cabin  Embarked
# 0  False   True     False
# 1  False  False     False
# 2  False   True     False

# %%
titanic_df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
titanic_df_drop = titanic_df.dropna()
titanic_df_drop.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
titanic_df['Cabin'] = titanic_df['Cabin'].fillna('C000')
titanic_df.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500  C000        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250  C000        S

# %%
titanic_df[titanic_df['Age'].isnull()]
# Out:
#      PassengerId  Survived  Pclass  \
# 5              6         0       3
# 17            18         1       2
# 19            20         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 31            32         1       1
# 32            33         1       3
# 36            37         1       3
# 42            43         0       3
# 45            46         0       3
# 46            47         0       3
# 47            48         1       3
# 48            49         0       3
# 55            56         1       1
# 64            65         0       1
# 65            66         1       3
# 76            77         0       3
# 77            78         0       3
# 82            83         1       3
# 87            88         0       3
# 95            96         0       3
# 101          102         0       3
# 107          108         1       3
# 109          110         1       3
# 121          122         0       3
# 126          127         0       3
# 128          129         1       3
# 140          141         0       3
# 154          155         0       3
# ..           ...       ...     ...
# 718          719         0       3
# 727          728         1       3
# 732          733         0       2
# 738          739         0       3
# 739          740         0       3
# 740          741         1       1
# 760          761         0       3
# 766          767         0       1
# 768          769         0       3
# 773          774         0       3
# 776          777         0       3
# 778          779         0       3
# 783          784         0       3
# 790          791         0       3
# 792          793         0       3
# 793          794         0       1
# 815          816         0       1
# 825          826         0       3
# 826          827         0       3
# 828          829         1       3
# 832          833         0       3
# 837          838         0       3
# 839          840         1       1
# 846          847         0       3
# 849          850         1       1
# 859          860         0       3
# 863          864         0       3
# 868          869         0       3
# 878          879         0       3
# 888          889         0       3
#
#                                                Name     Sex  Age  SibSp  \
# 5                                  Moran, Mr. James    male  NaN      0
# 17                     Williams, Mr. Charles Eugene    male  NaN      0
# 19                          Masselmani, Mrs. Fatima  female  NaN      0
# 26                          Emir, Mr. Farred Chehab    male  NaN      0
# 28                    O'Dwyer, Miss. Ellen "Nellie"  female  NaN      0
# 29                              Todoroff, Mr. Lalio    male  NaN      0
# 31   Spencer, Mrs. William Augustus (Marie Eugenie)  female  NaN      1
# 32                         Glynn, Miss. Mary Agatha  female  NaN      0
# 36                                 Mamee, Mr. Hanna    male  NaN      0
# 42                              Kraeff, Mr. Theodor    male  NaN      0
# 45                         Rogers, Mr. William John    male  NaN      0
# 46                                Lennon, Mr. Denis    male  NaN      1
# 47                        O'Driscoll, Miss. Bridget  female  NaN      0
# 48                              Samaan, Mr. Youssef    male  NaN      2
# 55                                Woolner, Mr. Hugh    male  NaN      0
# 64                            Stewart, Mr. Albert A    male  NaN      0
# 65                         Moubarek, Master. Gerios    male  NaN      1
# 76                                Staneff, Mr. Ivan    male  NaN      0
# 77                         Moutal, Mr. Rahamin Haim    male  NaN      0
# 82                   McDermott, Miss. Brigdet Delia  female  NaN      0
# 87                    Slocovski, Mr. Selman Francis    male  NaN      0
# 95                      Shorney, Mr. Charles Joseph    male  NaN      0
# 101                Petroff, Mr. Pastcho ("Pentcho")    male  NaN      0
# 107                          Moss, Mr. Albert Johan    male  NaN      0
# 109                             Moran, Miss. Bertha  female  NaN      1
# 121                      Moore, Mr. Leonard Charles    male  NaN      0
# 126                             McMahon, Mr. Martin    male  NaN      0
# 128                               Peter, Miss. Anna  female  NaN      1
# 140                   Boulos, Mrs. Joseph (Sultana)  female  NaN      0
# 154                           Olsen, Mr. Ole Martin    male  NaN      0
# ..                                              ...     ...  ...    ...
# 718                             McEvoy, Mr. Michael    male  NaN      0
# 727                        Mannion, Miss. Margareth  female  NaN      0
# 732                            Knight, Mr. Robert J    male  NaN      0
# 738                              Ivanoff, Mr. Kanio    male  NaN      0
# 739                              Nankoff, Mr. Minko    male  NaN      0
# 740                     Hawksford, Mr. Walter James    male  NaN      0
# 760                              Garfirth, Mr. John    male  NaN      0
# 766                       Brewe, Dr. Arthur Jackson    male  NaN      0
# 768                             Moran, Mr. Daniel J    male  NaN      1
# 773                                 Elias, Mr. Dibo    male  NaN      0
# 776                                Tobin, Mr. Roger    male  NaN      0
# 778                         Kilgannon, Mr. Thomas J    male  NaN      0
# 783                          Johnston, Mr. Andrew G    male  NaN      1
# 790                        Keane, Mr. Andrew "Andy"    male  NaN      0
# 792                         Sage, Miss. Stella Anna  female  NaN      8
# 793                        Hoyt, Mr. William Fisher    male  NaN      0
# 815                                Fry, Mr. Richard    male  NaN      0
# 825                                 Flynn, Mr. John    male  NaN      0
# 826                                    Lam, Mr. Len    male  NaN      0
# 828                    McCormack, Mr. Thomas Joseph    male  NaN      0
# 832                                  Saad, Mr. Amin    male  NaN      0
# 837                             Sirota, Mr. Maurice    male  NaN      0
# 839                            Marechal, Mr. Pierre    male  NaN      0
# 846                        Sage, Mr. Douglas Bullen    male  NaN      8
# 849    Goldenberg, Mrs. Samuel L (Edwiga Grabowska)  female  NaN      1
# 859                                Razi, Mr. Raihed    male  NaN      0
# 863               Sage, Miss. Dorothy Edith "Dolly"  female  NaN      8
# 868                     van Melkebeke, Mr. Philemon    male  NaN      0
# 878                              Laleff, Mr. Kristo    male  NaN      0
# 888        Johnston, Miss. Catherine Helen "Carrie"  female  NaN      1
#
#      Parch           Ticket      Fare  Cabin Embarked
# 5        0           330877    8.4583   C000        Q
# 17       0           244373   13.0000   C000        S
# 19       0             2649    7.2250   C000        C
# 26       0             2631    7.2250   C000        C
# 28       0           330959    7.8792   C000        Q
# 29       0           349216    7.8958   C000        S
# 31       0         PC 17569  146.5208    B78        C
# 32       0           335677    7.7500   C000        Q
# 36       0             2677    7.2292   C000        C
# 42       0           349253    7.8958   C000        C
# 45       0  S.C./A.4. 23567    8.0500   C000        S
# 46       0           370371   15.5000   C000        Q
# 47       0            14311    7.7500   C000        Q
# 48       0             2662   21.6792   C000        C
# 55       0            19947   35.5000    C52        S
# 64       0         PC 17605   27.7208   C000        C
# 65       1             2661   15.2458   C000        C
# 76       0           349208    7.8958   C000        S
# 77       0           374746    8.0500   C000        S
# 82       0           330932    7.7875   C000        Q
# 87       0  SOTON/OQ 392086    8.0500   C000        S
# 95       0           374910    8.0500   C000        S
# 101      0           349215    7.8958   C000        S
# 107      0           312991    7.7750   C000        S
# 109      0           371110   24.1500   C000        Q
# 121      0        A4. 54510    8.0500   C000        S
# 126      0           370372    7.7500   C000        Q
# 128      1             2668   22.3583  F E69        C
# 140      2             2678   15.2458   C000        C
# 154      0        Fa 265302    7.3125   C000        S
# ..     ...              ...       ...    ...      ...
# 718      0            36568   15.5000   C000        Q
# 727      0            36866    7.7375   C000        Q
# 732      0           239855    0.0000   C000        S
# 738      0           349201    7.8958   C000        S
# 739      0           349218    7.8958   C000        S
# 740      0            16988   30.0000    D45        S
# 760      0           358585   14.5000   C000        S
# 766      0           112379   39.6000   C000        C
# 768      0           371110   24.1500   C000        Q
# 773      0             2674    7.2250   C000        C
# 776      0           383121    7.7500    F38        Q
# 778      0            36865    7.7375   C000        Q
# 783      2       W./C. 6607   23.4500   C000        S
# 790      0            12460    7.7500   C000        Q
# 792      2         CA. 2343   69.5500   C000        S
# 793      0         PC 17600   30.6958   C000        C
# 815      0           112058    0.0000   B102        S
# 825      0           368323    6.9500   C000        Q
# 826      0             1601   56.4958   C000        S
# 828      0           367228    7.7500   C000        Q
# 832      0             2671    7.2292   C000        C
# 837      0           392092    8.0500   C000        S
# 839      0            11774   29.7000    C47        C
# 846      2         CA. 2343   69.5500   C000        S
# 849      0            17453   89.1042    C92        C
# 859      0             2629    7.2292   C000        C
# 863      2         CA. 2343   69.5500   C000        S
# 868      0           345777    9.5000   C000        S
# 878      0           349217    7.8958   C000        S
# 888      2       W./C. 6607   23.4500   C000        S
#
# [177 rows x 12 columns]

# %%
titanic_df['Age'] = titanic_df['Age'].fillna(titanic_df['Age'].mean())
titanic_df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex        Age  \
# 0                            Braund, Mr. Owen Harris    male  22.000000
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                             Heikkinen, Miss. Laina  female  26.000000
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                           Allen, Mr. William Henry    male  35.000000
# 5                                   Moran, Mr. James    male  29.699118
# 6                            McCarthy, Mr. Timothy J    male  54.000000
# 7                     Palsson, Master. Gosta Leonard    male   2.000000
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.000000
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.000000
#
#    SibSp  Parch            Ticket     Fare Cabin Embarked
# 0      1      0         A/5 21171   7.2500  C000        S
# 1      1      0          PC 17599  71.2833   C85        C
# 2      0      0  STON/O2. 3101282   7.9250  C000        S
# 3      1      0            113803  53.1000  C123        S
# 4      0      0            373450   8.0500  C000        S
# 5      0      0            330877   8.4583  C000        Q
# 6      0      0             17463  51.8625   E46        S
# 7      3      1            349909  21.0750  C000        S
# 8      0      2            347742  11.1333  C000        S
# 9      1      0            237736  30.0708  C000        C

# %%
titanic_df['Embarked'] = titanic_df['Embarked'].fillna('N')
titanic_df.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500  C000        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250  C000        S

# %%
titanic_df_groupby = titanic_df.groupby(by = "Pclass")
type(titanic_df_groupby)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
titanic_df[['Age','Fare']].mean()
# Out:
# Age     29.699118
# Fare    32.204208
# dtype: float64

# %%
titanic_df_groupby= titanic_df.groupby(by='Pclass').count()
titanic_df_groupby.head()
# Out:
#         PassengerId  Survived  Name  Sex  Age  SibSp  Parch  Ticket  Fare  \
# Pclass
# 1               216       216   216  216  216    216    216     216   216
# 2               184       184   184  184  184    184    184     184   184
# 3               491       491   491  491  491    491    491     491   491
#
#         Cabin  Embarked
# Pclass
# 1         216       216
# 2         184       184
# 3         491       491

# %%
titanic_df_groupby = titanic_df.groupby(by='Pclass')[['PassengerId','Survived']].count()
titanic_df_groupby.head()
# Out:
#         PassengerId  Survived
# Pclass
# 1               216       216
# 2               184       184
# 3               491       491

# %%
titanic_df_groupby = titanic_df.groupby(by='Pclass')[['Age']].agg([min, max])
titanic_df_groupby.head()
# Out:
#          Age
#          min   max
# Pclass
# 1       0.92  80.0
# 2       0.67  70.0
# 3       0.42  74.0

# %%
agg_format={'Age':'max', 'SibSp':'sum', 'Fare':'mean'}
titanic_df.groupby(by = 'Pclass').agg(agg_format)
# Out:
#          Age  SibSp       Fare
# Pclass
# 1       80.0     90  84.154687
# 2       70.0     74  20.662183
# 3       74.0    302  13.675550

# %%
pd.pivot_table(titanic_df, index=['Pclass'])
# Out:
#               Age       Fare     Parch  PassengerId     SibSp  Survived
# Pclass
# 1       37.048118  84.154687  0.356481   461.597222  0.416667  0.629630
# 2       29.866958  20.662183  0.380435   445.956522  0.402174  0.472826
# 3       26.403259  13.675550  0.393075   439.154786  0.615071  0.242363

# %%
pd.pivot_table(titanic_df, index=['Pclass','Sex'], values=['Fare'],aggfunc=np.sum)
# Out:
#                     Fare
# Pclass Sex
# 1      female  9975.8250
#        male    8201.5875
# 2      female  1669.7292
#        male    2132.1125
# 3      female  2321.1086
#        male    4393.5865

# %%
pd.pivot_table(titanic_df, index=['Pclass','Sex'], values=['Age','Fare'], aggfunc = [np.mean, np.sum], fill_value=0, margins= True)
# Out:
#                     mean                       sum
#                      Age        Fare           Age        Fare
# Pclass Sex
# 1      female  34.141405  106.125798   3209.292059   9975.8250
#        male    39.287717   67.226127   4793.101471   8201.5875
# 2      female  28.748661   21.970121   2184.898235   1669.7292
#        male    30.653908   19.741782   3310.622059   2132.1125
# 3      female  24.068493   16.118810   3465.862941   2321.1086
#        male    27.372153   12.661633   9498.137059   4393.5865
# All            29.699118   32.204208  26461.913824  28693.9493

# %%
def get_square(a):
    return a**2
print('3의 제곱은 :', get_square(3))
# Out:
# 3의 제곱은 : 9

# %%
lambda_sqaure = lambda x : x**2
print('3의 제곱은 :', lambda_sqaure(3))
# Out:
# 3의 제곱은 : 9

# %%
titanic_df['Name_len'] = titanic_df['Name'].apply(lambda x : len(x))
titanic_df[['Name','Name_len']].head()
# Out:
#                                                 Name  Name_len
# 0                            Braund, Mr. Owen Harris        23
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...        51
# 2                             Heikkinen, Miss. Laina        22
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)        44
# 4                           Allen, Mr. William Henry        24

# %%
titanic_df['Age_Cat'] = titanic_df['Age'].apply(lambda x : 'Child' if x <= 15 else 'adult'if x<=60 else 'Elderly')
titanic_df[['Age','Age_Cat']].head()
# Out:
#     Age Age_Cat
# 0  22.0   adult
# 1  38.0   adult
# 2  26.0   adult
# 3  35.0   adult
# 4  35.0   adult

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
sns.catplot(x='day', y= 'total_bill', data=tips, kind='box')

# %%
sns.catplot(x='day', y= 'total_bill', data=tips, kind='violin',split = True, hue='sex')

# %%
sns.lmplot(x='total_bill', y= 'tip', data = tips, hue = 'smoker', markers=['s','*'], size=7)
plt.show()

# %%
flights = sns.load_dataset('flights')
flights.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
flights = flights.pivot(index='month',columns='year',values='passengers')
flights.head()
# Out:
# year      1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  \
# month
# January    112   115   145   171   196   204   242   284   315   340   360
# February   118   126   150   180   196   188   233   277   301   318   342
# March      132   141   178   193   236   235   267   317   356   362   406
# April      129   135   163   181   235   227   269   313   348   348   396
# May        121   125   172   183   229   234   270   318   355   363   420
#
# year      1960
# month
# January    417
# February   391
# March      419
# April      461
# May        472

# %%
sns.heatmap(flights, annot=True, fmt='d', linewidths=5)

# %%
sns.set_style=('tips')
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.pairplot(iris, hue='species')

# %%
sns.pairplot(iris, hue='species', vars=['sepal_width', 'sepal_length'])

# %%
sns.pairplot(iris, kind='reg', size=3)
plt.show()
